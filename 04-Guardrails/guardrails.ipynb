# %%
# !pip install -U "guardrails-ai>=0.6.7"
# Out:
# ...
#   Attempting uninstall: opentelemetry-api90m━━━━━━━━━━━━━━━━━━━━━━ 11/25 [guardrails-hub-types]
#     Found existing installation: opentelemetry-api 1.32.1━━━━━ 11/25 [guardrails-hub-types]
#     Uninstalling opentelemetry-api-1.32.1:━━━━━━━━━━━━━━━━━━━━ 11/25 [guardrails-hub-types]
#       Successfully uninstalled opentelemetry-api-1.32.1━━━━━━━ 11/25 [guardrails-hub-types]
#   Attempting uninstall: opentelemetry-semantic-conventions━━━━ 11/25 [guardrails-hub-types]
#     Found existing installation: opentelemetry-semantic-conventions 0.53b1/25 [guardrails-hub-types]
#     Uninstalling opentelemetry-semantic-conventions-0.53b1:━━━ 11/25 [guardrails-hub-types]
#       Successfully uninstalled opentelemetry-semantic-conventions-0.53b111/25 [guardrails-hub-types]
#   Attempting uninstall: opentelemetry-sdk╺━━━━━━━━━ 18/25 [opentelemetry-semantic-conventions]
#     Found existing installation: opentelemetry-sdk 1.32.1 18/25 [opentelemetry-semantic-conventions]
# ...

# %%
# !guardrails configure
# Out:
# Enable anonymous metrics reporting? [Y/n]: ^C
